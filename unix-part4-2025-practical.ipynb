# %% [markdown]
# # Programmation Bash - exercices
#
# ## Préparation des données
#
# Supprimez tout d'abord les éventuels fichiers résiduels en exécutant la cellule suivante :

# %%
#IN [1]
rm -rf genoms genoms.gz staphylo.tgz

# %% [markdown]
# Téléchargez ensuite le fichier `genoms.gz` avec la commande :

# %%
#IN [2]
wget https://raw.githubusercontent.com/Marwa-ZI/programmation_bash/main/genoms.gz
# Out:
# --2025-09-18 20:35:26--  https://raw.githubusercontent.com/Marwa-ZI/programmation_bash/main/genoms.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64398 (63K) [application/octet-stream]
# Saving to: ‘genoms.gz’
#
# genoms.gz           100%[===================>]  62.89K  --.-KB/s    in 0.01s
#
# 2025-09-18 20:35:26 (6.35 MB/s) - ‘genoms.gz’ saved [64398/64398]

# %%
#IN [3]
ls -lh
# Out:
# total 144K
# -rw-rw-r-- 1 mzidi mzidi  350 Sep 10 07:46 arg.sh
# -rw-rw-r-- 1 mzidi mzidi  39K Sep 10 08:04 bash-introduction.ipynb
# -rw-rw-r-- 1 mzidi mzidi 5.8K Sep 10 10:11 bash-practical.ipynb
# -rw-rw-r-- 1 mzidi mzidi  240 Sep 10 07:46 exit.sh
# -rw-rw-r-- 1 mzidi mzidi   62 Sep 10 07:46 haiku.txt
# -rw-rw-r-- 1 mzidi mzidi  63K Sep 10 10:10 mon_fichier.gz
# -rw-rw-r-- 1 mzidi mzidi  372 Sep 10 07:46 people.dat
# -rwxrwxr-x 1 mzidi mzidi   43 Sep 10 07:46 script.sh
# -rw-rw-r-- 1 mzidi mzidi   72 Sep 10 08:04 Untitled.ipynb
# -rw-rw-r-- 1 mzidi mzidi  301 Sep 10 07:46 var.sh
# -rw-rw-r-- 1 mzidi mzidi   96 Sep 10 07:46 while.sh

# %% [markdown]
# *Remarque.* Si la commande `wget` n'est pas disponible, essayez d'utiliser la commande `curl` :
# ```
# curl -o genoms.gz https://raw.githubusercontent.com/Marwa-ZI/programmation_bash/main/genoms.gz
# ```

# %% [markdown]
# Ce fichier contient les fichiers GenBank tronqués de quelques organismes (les dix premières lignes seulement).
#
# ## Découverte du jeu de données
#
# 1. Décompressez l'archive `genoms.gz` que vous avez téléchargée.
#
# Utilisez pour cela la commande `gunzip ou gzip -d`. Vous trouverez un rappel des différentes options [ici](https://www.geeksforgeeks.org/linux-unix/gunzip-command-in-linux-with-examples/).

# %%
#IN [4]

# %% [markdown]
# 2. Combien de fichiers contient le répertoire `genoms` qui a été créé ? Utilisez, une (ou plusieurs) commande(s) Unix pour répondre. 😎

# %%
#IN [5]

# %% [markdown]
# 3. Familiarisez-vous avec les fichiers GenBank contenu dans le répertoire `genoms`. Combien de lignes y-a-t-il dans chaque fichiers ?

# %%
#IN [6]

# %% [markdown]
# 4. Quelle ligne des fichiers GenBank permet de savoir si l'organisme concerné est un staphylocoque ?
#
# Par exemple, le fichier *NC_002976_head.gbk* est un fichier d'un staphylocoque alors que *NC_002505_head.gbk* non.

# %%
#IN [7]

# %% [markdown]
# ## Extraction automatique des staphylocoques
#
# Supprimez maintenant le répertoire `genoms` :

# %%
#IN [8]

# %% [markdown]
# Si le fichier `genoms.gz` n'est plus présent dans votre répertoire, pensez à le télécharger à nouveau.
#
# Écrivez le script bash `get_staphylo.sh` qui s'exécute dans le même répertoire que `genoms.gz` et qui :
#
# 1. décompresse l'archive `genoms.gz` ;
# 2. crée un répertoire `staphylo`, au même niveau que le répertoire `genoms` qui contient les fichiers GenBank ;
# 3. décide si le fichier GenBank contient un génome de staphylocoques ou pas ;
# 4. affiche les noms des fichiers GenBank de staphylocoques ;
# 5. copie ces fichiers dans le répertoire `staphylo` ;
# 6. archive et compresse le répertoire `staphylo` sous le nom `staphylo.tgz` ;
# 7. supprime les répertoires `genoms` et `staphylo`.

# %%
#IN [9]

# %% [markdown]
# ## Aide Notebook
#
# *To make nice HTML reports with markdown:*
# - [html visualization tool 1](https://dillinger.io/)
# - [html visualization tool 2](https://stackedit.io/app#)
# - [to draw nice tables](https://www.tablesgenerator.com/markdown_tables)
# - [Ultimate guide](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd)
#
# *Further reading on JupyterLab notebooks:*
# - [Jupyter Lab documentation](https://jupyterlab.readthedocs.io/en/latest/user/notebook.html)
#
# *Here we are using JupyterLab interface implemented as part of the [Plasmabio](https://plasmabio.org/) project led by Sandrine Caburet, Pierre Poulain and Claire Vandiedonck.*
#
# *Last version revised on 18/09/2025 by Marwa ZIDI*
